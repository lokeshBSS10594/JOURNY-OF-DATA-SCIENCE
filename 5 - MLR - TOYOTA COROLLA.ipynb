# %% [markdown]
# # TOYOTA COROLLA - Consider only the below columns and prepare a prediction model for predicting Price

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from numpy.polynomial.polynomial import polyfit
from sklearn.linear_model import LinearRegression
import seaborn as sns
import statsmodels.stats.tests.test_influence
from sklearn.feature_selection import RFE
from statsmodels.stats.outliers_influence import variance_inflation_factor
import math

# %%
Toyota=pd.read_csv('ToyotaCorolla.csv',encoding='latin1')
Toyota.head(2)
# Out:
#    Id                                          Model  Price  Age_08_04  \
# 0   1  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# 0                1               1      0          0            0
# 1                0               1      0          0            0
#
#    Backseat_Divider  Metallic_Rim  Radio_cassette  Tow_Bar
# 0                 1             0               0        0
# 1                 1             0               0        0
#
# [2 rows x 38 columns]

# %%
Toyota1 = Toyota[['Price','Age_08_04','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight']]
Toyota1.head(2)
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165

# %%
Toyota1.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears',
#        'Quarterly_Tax', 'Weight'],
#       dtype='object')

# %%
Toyota1.count()
# Out:
# Price            1436
# Age_08_04        1436
# KM               1436
# HP               1436
# cc               1436
# Doors            1436
# Gears            1436
# Quarterly_Tax    1436
# Weight           1436
# dtype: int64

# %%
Toyota1.shape
# Out:
# (1436, 9)

# %%
Toyota1.dtypes
# Out:
# Price            int64
# Age_08_04        int64
# KM               int64
# HP               int64
# cc               int64
# Doors            int64
# Gears            int64
# Quarterly_Tax    int64
# Weight           int64
# dtype: object

# %%
Toyota1.describe()
# Out:
#               Price    Age_08_04             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears  Quarterly_Tax      Weight
# count  1436.000000  1436.000000    1436.000000  1436.00000
# mean      4.033426     5.026462      87.122563  1072.45961
# std       0.952677     0.188510      41.128611    52.64112
# min       2.000000     3.000000      19.000000  1000.00000
# ...

# %%
Toyota1.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876590 -0.569960  0.314990  0.126389  0.185326
# Age_08_04     -0.876590   1.000000  0.505672 -0.156622 -0.098084 -0.148359
# KM            -0.569960   0.505672  1.000000 -0.333538  0.102683 -0.036197
# HP             0.314990  -0.156622 -0.333538  1.000000  0.035856  0.092424
# cc             0.126389  -0.098084  0.102683  0.035856  1.000000  0.079903
# Doors          0.185326  -0.148359 -0.036197  0.092424  0.079903  1.000000
# Gears          0.063104  -0.005364  0.015023  0.209477  0.014629 -0.160141
# Quarterly_Tax  0.219197  -0.198431  0.278165 -0.298432  0.306996  0.109363
# Weight         0.581198  -0.470253 -0.028598  0.089614  0.335637  0.302618
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063104       0.219197  0.581198
# Age_08_04     -0.005364      -0.198431 -0.470253
# KM             0.015023       0.278165 -0.028598
# ...

# %%
sns.heatmap(Toyota1.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
X = Toyota1[['Age_08_04','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight']]
Y = Toyota1[['Price']]

# %%
model = sm.OLS(Y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                          1.247e+04
# Date:                Fri, 18 Nov 2022   Prob (F-statistic):                        0.00
# Time:                        20:55:08   Log-Likelihood:                         -12383.
# No. Observations:                1436   AIC:                                  2.478e+04
# Df Residuals:                    1428   BIC:                                  2.482e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### MODEL IS ACCEPTED.
#
# BUT, THIERE IS STROGN MULTICOLLINEARITY IN THE DATASET.

# %%
model1 = model.get_influence()

# %%
summ_Toyota = model1.summary_frame()
summ_Toyota.sort_values('cooks_d', ascending=False)
# Out:
#       dfb_Age_08_04        dfb_KM    dfb_HP        dfb_cc  dfb_Doors  \
# 80        -0.289686 -2.363023e+00 -2.781734  2.615263e+01   0.645518
# 221       -0.255051 -2.607849e-02  0.174427  4.179288e-01   0.553762
# 960       -0.208597  3.740370e-02  0.443719  1.977218e-01   0.539659
# 109        0.104572 -2.934313e-01  0.114571 -1.902240e-01  -0.220145
# 601       -0.213100  3.186680e-01  0.385097 -1.107466e-01   0.404397
# ...             ...           ...       ...           ...        ...
# 1167      -0.000069 -5.512316e-05  0.000142  6.568459e-05   0.000134
# 482       -0.000005  2.712110e-08 -0.000085  2.916558e-07  -0.000162
# 1433      -0.000136  1.856487e-04  0.000104  1.209905e-05   0.000052
# 397       -0.000015  4.001993e-05  0.000028  1.344847e-06  -0.000098
# 922       -0.000027  1.632787e-05 -0.000027 -8.283992e-06   0.000052
#
#       dfb_Gears  dfb_Quarterly_Tax  dfb_Weight       cooks_d  standard_resid  \
# ...

# %%
model1.plot_influence()

# %% [markdown]
# index 80 has highest Cook's therefore we drop this row from the data set

# %% [markdown]
# # Finding Variance Inflation Factor (VIF)

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# %%
vif["features"] = X.columns

# %%
vif.round(1)
# Out:
#    VIF Factor       features
# 0        16.4      Age_08_04
# 1         7.6             KM
# 2        64.9             HP
# 3        17.2             cc
# 4        21.9          Doors
# 5       438.6          Gears
# 6        11.0  Quarterly_Tax
# 7       543.1         Weight

# %% [markdown]
# Geras and Weight have a high variance inflation factor. Therefore, we shall drop "Gears" and solve multicollinearity

# %%
# Removed Gears fron the dataframe and Tested the model
new_x = Toyota1[['Age_08_04','KM','HP','cc','Doors','Weight','Quarterly_Tax']]
new_x.head(2)
# Out:
#    Age_08_04     KM  HP    cc  Doors  Weight  Quarterly_Tax
# 0         23  46986  90  2000      3    1165            210
# 1         23  72937  90  2000      3    1165            210

# %%
new_model = sm.OLS(Y, new_x).fit()
new_predictions = new_model.predict(new_x)
new_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                          1.426e+04
# Date:                Fri, 18 Nov 2022   Prob (F-statistic):                        0.00
# Time:                        21:26:33   Log-Likelihood:                         -12383.
# No. Observations:                1436   AIC:                                  2.478e+04
# Df Residuals:                    1429   BIC:                                  2.482e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# Their is no multicollinearity and the variables are significant after removing the vairable "Gears" from the dataset

# %% [markdown]
# # Final Model

# %%
# Removed Index with highest Cook's distance to remove the hightest influencial ROW
new_df = Toyota1.drop(Toyota1.index[80])

# %%
new_X = new_df[['Age_08_04','KM','HP','cc','Doors','Weight','Quarterly_Tax']]
new_Y = new_df[['Price']]
final_model = sm.OLS(new_Y, new_X).fit()
predictions = final_model.predict(new_X)

# %%
final_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                          1.484e+04
# Date:                Fri, 18 Nov 2022   Prob (F-statistic):                        0.00
# Time:                        21:31:43   Log-Likelihood:                         -12345.
# No. Observations:                1435   AIC:                                  2.470e+04
# Df Residuals:                    1428   BIC:                                  2.474e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# # it has R-squared of 0.986. i.e; 98.6% accuracy.
